# %% [markdown]
# # Análisis de Correlaciones Canónicas
# Identificar y medir las asociaciones entre dos conjuntos de variables

# %%
# Out:
# Warning message:
# "unable to access index for repository https://cran.r-project.org/src/contrib:
#   cannot open destfile 'C:\Users\GAMER\AppData\Local\Temp\Rtmp00tsHA\file6184f3a548d', reason 'No such file or directory'"Warning message:
# "package 'CCA' is not available (for R version 3.6.1)"Warning message in gzfile(file, mode):
# "cannot open compressed file 'C:\Users\GAMER\AppData\Local\Temp\Rtmp00tsHA/libloc_202_16e9a632.rds', probable reason 'No such file or directory'"
# Error in gzfile(file, mode): no se puede abrir la conexión
# Traceback:
#
# 1. install.packages("CCA")
# 2. getDependencies(pkgs, dependencies, available, lib, ...)
# 3. installed.packages(lib.loc = libpath, fields = c("Package", "Version"),
#  .     ...)
# 4. saveRDS(list(base = base, value = ret0), dest)
# 5. gzfile(file, mode)

# %%
library("dplyr")
library("ggplot2")
library("GGally")
library('CCA')
# Out:
# Error in library("CCA"): there is no package called 'CCA'
# Traceback:
#
# 1. library("CCA")

# %%
df <- read.csv("CCA.csv")

# %%
df_1 = select(df,temperature,population,co2)
df_2 = select(df,forest,electricprod,agriculture)

# %%
df_1
# Out:
#      temperature population co2
# 1    13.4490      3286542    5515.168
# 2    11.5885      3266790    4286.723
# 3    13.5850      3247039    2515.562
# 4    13.6500      3227287    2335.879
# 5    13.2390      3207536    1925.175
# 6    11.8750      3187784    2086.523
# 7    11.7315      3168033    2016.850
# 8    10.7790      3148281    1543.807
# 9    13.4790      3128530    1752.826
# 10   13.5485      3108778    2984.938
# 11   13.9625      3089027    3021.608
# 12   13.7490      3060173    3223.293
# 13   12.5335      3051010    3751.341
# 14   12.1450      3039616    4294.057
# 15   13.6610      3026939    4165.712
# 16   12.4485      3011487    4253.720
# 17   13.6685      2992547    3898.021
# 18   13.1770      2970017    3927.357
# 19   13.2985      2947314    4374.731
# 20   13.1795      2927519    4378.398
# 21   12.6825      2913021    4598.418
# 22   12.4440      2905195    5240.143
# 23   13.9060      2900401    4924.781
# 24   15.9465      2895092    4913.780
# ...
